# %% [markdown]
# # Importing the useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import sklearn.neighbors._base 
import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest
#from sklearn.impute import KNNImputer

# %% [markdown]
# ## Setting to display the full data in columns and rows

# %% [markdown]
# pd.set_option('display.max_column',300)
# pd.set_option('display.max_row',200)

# %% [markdown]
# ## Reading the data from CSV file

# %%
data = pd.read_csv('C:\\Users\\User\\Downloads\\cars_engage_2022.csv',index_col=0)

# %% [markdown]
# ## General Observation

# %%
print(data.tail())
data.shape
# Out:
#             Make    Model        Variant Ex-Showroom_Price Displacement  \
# 1271       Honda     City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda     City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda     City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda     City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi  Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 1271        4.0                  4.0  FWD (Front Wheel Drive)
# 1272        4.0                  4.0  FWD (Front Wheel Drive)
# 1273        4.0                  4.0  FWD (Front Wheel Drive)
# 1274        4.0                  4.0  FWD (Front Wheel Drive)
# 1275        4.0                  4.0    AWD (All Wheel Drive)
#
#      Cylinder_Configuration Emission_Norm      Engine_Location Fuel_System  \
# 1271                In-line         BS IV    Front, Transverse   Injection
# ...

# %% [markdown]
# ## Dropping duplicate values

# %%
clean_data = data.copy()
clean_data.drop_duplicates(keep='first',inplace=True)

# %%
print(data.shape)
clean_data.shape
# Out:
# (1276, 140)
# (1267, 140)

# %% [markdown]
# #### Nine rows have been dropped

# %% [markdown]
# ### Dealing with missing values

# %%
data1 = clean_data.select_dtypes(exclude=['object'])
imputer = MissForest() #miss forest
X_imputed = imputer.fit_transform(data1)
X_imputed = pd.DataFrame(X_imputed, columns = data1.columns).round(1)
print(data1.isnull().sum())
print(X_imputed.isnull().sum())

# %% [markdown]
# ## Value Counts of each variable individually

# %%
data2['Engine_Location'].value_counts()
# Out:
# Front, Transverse       796
# Front, Longitudinal     404
# Rear, Transverse         16
# Rear Mid, Transverse      3
# Mid, Longitudinal         2
# Mid, Transverse           2
# Rear, Longitudinal        1
# Name: Engine_Location, dtype: int64

# %%
data2['Fuel_System'].value_counts()
# Out:
# Injection    1255
# PGM - Fi        4
# Name: Fuel_System, dtype: int64

# %%
sns.countplot(data2['Fuel_Tank_Capacity'])
# Out:
# <AxesSubplot:xlabel='Fuel_Tank_Capacity', ylabel='count'>

# %%
data2['Fuel_Type'].value_counts()
# Out:
# Petrol          642
# Diesel          574
# CNG              16
# Hybrid           15
# Electric         14
# CNG + Petrol      6
# Name: Fuel_Type, dtype: int64

# %%
data2['Highway_Mileage'].value_counts()
# Out:
# 22 km/litre         17
# 23 km/litre         16
# 16 km/litre         13
# 17 km/litre         13
# 11.12 km/litre      11
# 15.4 km/litre       11
# 25.32 km/litre      11
# 17.6 km/litre       11
# 18.15 km/litre      11
# 10.5 km/litre       10
# 24 km/litre          9
# 24.3 km/litre        9
# 20 km/litre          8
# 18 km/litre          7
# 18.19 km/litre       7
# 14.6 km/litre        7
# 19.6 km/litre        7
# 23.08 km/litre       7
# 13.6 km/litre        6
# 18.5 km/litre        6
# 12 km/litre          6
# 20.08 km/litre       6
# 15 km/litre          6
# 13.8 km/litre        6
# 17.9 km/litre        6
# 7.8 km/litre         6
# 17.71 km/litre       5
# 21.13 km/litre       5
# 15.41 km/litre       5
# 12.9 km/litre        4
# 6.2 km/litre         4
# 25 km/litre          4
# 15.7 km/litre        4
# 14.84 km/litre       4
# 19.77 km/litre       4
# 22.5 km/litre        4
# 15.5 km/litre        4
# 17.21 km/litre       4
# 14 km/litre          4
# 9 km/litre           4
# ...

# %%
X_imputed['Doors'].value_counts()
# Out:
# 5.0    831
# 4.0    362
# 2.0     62
# 3.0     12
# Name: Doors, dtype: int64

# %%
data2['ARAI_Certified_Mileage_for_CNG'].value_counts()
# Out:
# 14.16 km/kg    5
# 25 km/kg       4
# 30.48 km/kg    2
# 20 km/kg       2
# 13.96 km/kg    2
# 33.54 km/kg    2
# 10.8 km/kg     1
# 20.4 km/kg     1
# 26.6 km/kg     1
# 18.9 km/kg     1
# 32.26 km/kg    1
# 43 km/kg       1
# 31.79 km/kg    1
# 36 km/kg       1
# 20.5 km/kg     1
# 31.76 km/kg    1
# Name: ARAI_Certified_Mileage_for_CNG, dtype: int64

# %%
data2['Kerb_Weight'].value_counts()
# Out:
# 935 kg     21
# 1785 kg    16
# 810 kg     16
# 895 kg     16
# 1100 kg    14
#            ..
# 1879 kg     1
# 2132 kg     1
# 1085 kg     1
# 1905 kg     1
# 1595 kg     1
# Name: Kerb_Weight, Length: 336, dtype: int64

# %%
data2['Gears'].value_counts()
# Out:
# 5                              614
# 6                              224
# 8                              139
# 7                              137
# 9                               30
# 4                               16
# Single Speed Reduction Gear      1
# 7 Dual Clutch                    1
# Name: Gears, dtype: int64

# %%
data2['Ground_Clearance'].value_counts()
# Out:
# 165 mm      143
# 170 mm      138
# 200 mm       66
# 180 mm       65
# 190 mm       56
# 163 mm       54
# 205 mm       34
# 160 mm       29
# 210 mm       28
# 209 mm       25
# 152 mm       23
# 185 mm       20
# 155 mm       20
# 184 mm       19
# 167 mm       18
# 295.5 mm     14
# 174 mm       13
# 198 mm       11
# 192 mm       11
# 188 mm       10
# 175 mm       10
# 149 mm        9
# 164 mm        9
# 100 mm        9
# 215 mm        9
# 183 mm        8
# 157 mm        8
# 172 mm        7
# 135 mm        7
# 201 mm        5
# 225 mm        5
# 307 mm        5
# 220 mm        5
# 154 mm        5
# 182 mm        4
# 150 mm        4
# 125 mm        4
# 218 mm        4
# 161 mm        4
# 113 mm        4
# 211 mm        3
# 142 mm        3
# 212 mm        3
# 498 mm        3
# 158 mm        3
# 110 mm        3
# 195 mm        3
# 136 mm        2
# 133 mm        2
# 140 mm        2
# 186 mm        2
# 109 mm        2
# 208 mm        2
# 132 mm        2
# 213 mm        2
# ...

# %%
data2['Front_Brakes'].value_counts()
# Out:
# Ventilated Disc    1159
# Solid Disc           73
# Drum                 10
# Name: Front_Brakes, dtype: int64

# %%
data2['Rear_Brakes'].value_counts()
# Out:
# Drum               782
# Ventilated Disc    417
# Solid Disc          43
# Name: Rear_Brakes, dtype: int64

# %%
data2['Front_Suspension'].value_counts()
# Out:
# MacPherson Strut                                                                                                                                                                                       119
# McPherson Strut                                                                                                                                                                                         89
# McPherson Strut, Coil Spring                                                                                                                                                                            54
# McPherson strut with coil spring                                                                                                                                                                        53
# ...

# %%
data2['Rear_Suspension'].value_counts()
# Out:
# Torsion Beam                                                                                                                                                     123
# Coupled Torsion Beam Axle                                                                                                                                         57
# Twist Beam with Coil spring and Shock Absorber                                                                                                                    53
# Coupled Torsion Beam Axle with coil spring                                                                                                                        50
# Torsion Beam Coil Spring                                                                                                                                          37
# ...

# %%
data2['Rear_Track'].value_counts()
# Out:
# 1540 mm           29
# 1493 mm           27
# 1490 mm           22
# 1410 mm           21
# 1290 mm           21
# 1445 mm           18
# 1456 mm           18
# 1600 mm           15
# 1500 mm           15
# 1567 mm           15
# 1474 mm           14
# 1515 mm           12
# 1440 mm           11
# 1520 mm           11
# 1503 mm           11
# 1475 mm           10
# 1420 mm           10
# 1480 mm            9
# 1632 mm            8
# 1575 mm            8
# 1597 mm            8
# 1310 mm            8
# 1686 mm            7
# 1570 mm            7
# 1676 mm            7
# 1478 mm            7
# 1620 mm            7
# 1686.6 mm          7
# 1525 mm            7
# 1560 mm            7
# 1530 mm            6
# 1683 mm            6
# 1315 mm            6
# 1691 mm            6
# 1650 mm            6
# 1594 mm            6
# 1485 mm            6
# 1465 mm            5
# 1635 mm            5
# 1671 mm            5
# 1526 mm            5
# 1646 mm            5
# 1466 mm            4
# ...

# %%
data2['Front_Track'].value_counts()
# Out:
# 1490 mm           46
# 1540 mm           27
# 1479 mm           26
# 1505 mm           22
# 1460 mm           21
# 1420 mm           21
# 1560 mm           19
# 1600 mm           19
# 1440 mm           18
# 1295 mm           16
# 1468 mm           14
# 1475 mm           13
# 1520 mm           13
# 1450 mm           13
# 1668 mm           12
# 1400 mm           10
# 1530 mm           10
# 1679 mm           10
# 1457 mm           10
# 1515 mm            9
# 1692 mm            9
# 1626 mm            8
# 1595 mm            8
# 1692.4 mm          7
# 1586 mm            7
# 1690 mm            6
# 1571 mm            6
# 1305 mm            6
# 1325 mm            6
# 1569 mm            6
# 1570 mm            6
# 1624 mm            5
# 1597 mm            5
# 1580 mm            5
# 1280 mm            5
# 1555 mm            5
# 1985 mm            5
# 1630 mm            5
# 1611 mm            5
# 1500 mm            5
# 1605 mm            5
# 1618 mm            4
# 1686 mm            4
# ...

# %%
data2['Front_Tyre_&_Rim'].value_counts()
# Out:
# 185/60R15                 66
# 185/65R15                 43
# 175/65R14                 38
# 165/70R14                 32
# 205/65R16                 28
#                           ..
# 205/60 R16                 1
# 265/35ZR19                 1
# 195 R15 LT, 8PR Radial     1
# 245/35 ZR20                1
# 245/40ZR19                 1
# Name: Front_Tyre_&_Rim, Length: 234, dtype: int64

# %%
data2['Power_Steering'].value_counts()
# Out:
# Electric Power                     916
# Electro-Hydraulic                  137
# Yes                                 85
# Hydraulic Power                     71
# Electric Power, Hydraulic Power      1
# Name: Power_Steering, dtype: int64

# %%
data2['Power_Windows'].value_counts()
# Out:
# All Windows           1026
# Only Front Windows     144
# Name: Power_Windows, dtype: int64

# %%
data2['Power_Seats'].value_counts()
# Out:
# Yes                 208
# Yes, with memory    108
# Power seats          66
# Name: Power_Seats, dtype: int64

# %%
data2['Power'].value_counts()
# Out:
# 83PS@6000rpm       52
# 75PS@4000rpm       37
# 90PS@4000rpm       29
# 100PS@3750RPM      28
# 68PS@6000rpm       25
#                    ..
# 460PS@7000RPM       1
# 550PS@5750-6000     1
# 136 bhp             1
# 639PS@8250rpm       1
# 235PS@4250RPM       1
# Name: Power, Length: 372, dtype: int64

# %%
data2['Torque'].value_counts()
# Out:
# 90Nm@3500rpm           42
# 200Nm@1750rpm          42
# 114Nm@4000rpm          27
# 350Nm@1750-2500rpm     26
# 104Nm@4000rpm          22
#                        ..
# 420Nm@1600-2600rpm      1
# 1712Nm@1500-4000rpm     1
# 560Nm@1500-3000rpm      1
# 180Nm@1750rpm           1
# 207Nm@2200rpm           1
# Name: Torque, Length: 342, dtype: int64

# %%
data2['Odometer'].value_counts()
# Out:
# Digital            1051
# Analog               90
# Yes                  83
# Digital, Analog       1
# Name: Odometer, dtype: int64

# %%
data2['Speedometer'].value_counts()
# Out:
# Analog             974
# Digital            111
# Yes                 79
# Analog, Digital     57
# Digital, Analog      2
# Name: Speedometer, dtype: int64

# %%
data2['Tachometer'].value_counts()
# Out:
# Analog                  933
# Digital                 112
# Yes                     109
# Not on offer             72
# Analog, Digital          22
# Digital, Analog           5
# Analog, Not on offer      1
# Name: Tachometer, dtype: int64

# %%
data2['Tripmeter'].value_counts()
# Out:
# Yes     978
# 2       197
# 1        26
# 1, 2      7
# Name: Tripmeter, dtype: int64

# %%
data2['Seats_Material'].value_counts()
# Out:
# Fabric          737
# Leather         505
# Vinyl             9
# Polyurethene      4
# Name: Seats_Material, dtype: int64

# %%
data2['Type'].value_counts()
# Out:
# Manual       721
# Automatic    517
# AMT           18
# DCT            7
# CVT            3
# Name: Type, dtype: int64

# %%
clean_data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm   Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type  \
# ...

# %%
data2['Average_Speed'].value_counts()
# Out:
# Yes    760
# Name: Average_Speed, dtype: int64

# %%
data2['City_Mileage'].value_counts()
# Out:
# 12 km/litre           38
# 18 km/litre           26
# 16 km/litre           22
# 14 km/litre           20
# 23 km/litre           19
# 15.1 km/litre         16
# 20 km/litre           13
# 25.17 km/litre        12
# 16.3 km/litre         11
# 15.5 km/litre         11
# 22.25 km/litre        11
# 11.2 km/litre         11
# 8.6 km/litre          11
# 18.49 km/litre        10
# 19 km/litre           10
# 21.4 km/litre         10
# 13.3 km/litre          9
# 11.5 km/litre          9
# 9.5 km/litre           9
# 12.8 km/litre          9
# 13.2 km/litre          9
# 20.3 km/litre          9
# 19.2 km/litre          8
# 10.2 km/litre          8
# 15.29 km/litre         8
# 23.84 km/litre         7
# 5.6 km/litre           7
# 12.4 km/litre          7
# 6.5 km/litre           7
# 21.38 km/litre         7
# 18.9 km/litre          7
# 9 km/litre             7
# 21.04 km/litre         7
# 13.8 km/litre          6
# 18.4 km/litre          6
# 24.12 km/litre         6
# 17.01 km/litre         6
# ...

# %%
data2['Keyless_Entry'].value_counts()
# Out:
# Smart Key            449
# Remote               421
# Yes                  101
# Remote, Smart Key     21
# Smart Key, Remote      1
# Name: Keyless_Entry, dtype: int64

# %%
data2['Body_Type'].value_counts()
# Out:
# SUV                    438
# Sedan                  333
# Hatchback              316
# Coupe                   41
# MUV                     39
# MPV                     39
# Convertible             20
# Crossover               18
# Pick-up                  3
# Sports                   3
# Sedan, Coupe             2
# Crossover, SUV           2
# Sports, Convertible      2
# SUV, Crossover           2
# Sedan, Crossover         1
# Sports, Hatchback        1
# Coupe, Convertible       1
# Name: Body_Type, dtype: int64

# %%
clean_data.shape
# Out:
# (1267, 140)

# %%
print(data.size)
print(clean_data.size)
clean_data.columns
# Out:
# 178640
# 177380
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=140)

# %%
data1.corr()
# Out:
#                      Cylinders  Valves_Per_Cylinder     Doors  \
# Cylinders             1.000000            -0.000883 -0.507185
# Valves_Per_Cylinder  -0.000883             1.000000 -0.030135
# Doors                -0.507185            -0.030135  1.000000
# Seating_Capacity     -0.318647            -0.025239  0.519921
# Number_of_Airbags     0.459746             0.068351 -0.222279
# USB_Ports            -0.241612                  NaN  0.472499
#
#                      Seating_Capacity  Number_of_Airbags  USB_Ports
# Cylinders                   -0.318647           0.459746  -0.241612
# Valves_Per_Cylinder         -0.025239           0.068351        NaN
# Doors                        0.519921          -0.222279   0.472499
# Seating_Capacity             1.000000          -0.014340   0.278574
# Number_of_Airbags           -0.014340           1.000000   0.364222
# USB_Ports                    0.278574           0.364222   1.000000

# %%
data1['Valves_Per_Cylinder'].value_counts()
# Out:
# 4.0     1104
# 2.0       46
# 8.0        4
# 12.0       4
# 3.0        2
# 1.0        2
# 16.0       2
# 6.0        1
# Name: Valves_Per_Cylinder, dtype: int64

# %%
manu.countplot(data1['Valves_Per_Cylinder'])
# Out:
# <AxesSubplot:xlabel='Valves_Per_Cylinder', ylabel='count'>

# %%
data1['Doors'].value_counts()
# Out:
# 5.0    827
# 4.0    362
# 2.0     62
# 3.0     12
# Name: Doors, dtype: int64

# %%
manu.boxplot(data1['Doors'])
# Out:
# <AxesSubplot:xlabel='Doors'>

# %%
X_imputed.describe()
# Out:
#          Cylinders  Valves_Per_Cylinder        Doors  Seating_Capacity  \
# count  1267.000000          1267.000000  1267.000000       1267.000000
# mean      4.374507             3.972297     4.548540          5.258800
# std       1.638842             0.805225     0.748756          1.138133
# min       2.000000             1.000000     2.000000          2.000000
# 25%       4.000000             4.000000     4.000000          5.000000
# 50%       4.000000             4.000000     5.000000          5.000000
# 75%       4.000000             4.000000     5.000000          5.000000
# max      16.000000            16.000000     5.000000         16.000000
#
#        Number_of_Airbags    USB_Ports
# count        1267.000000  1267.000000
# mean            3.705604     1.946330
# std             2.442568     0.342824
# min             1.000000     1.000000
# 25%             2.000000     2.000000
# 50%             2.000000     2.000000
# 75%             6.000000     2.000000
# ...

# %%
data2 = clean_data.select_dtypes(include=['object'])

# %%
data2.describe()
# Out:
#                  Make  Model Variant Ex-Showroom_Price Displacement  \
# count            1192   1267    1267              1267         1255
# unique             39    263    1064              1179          129
# top     Maruti Suzuki  Nexon     Vxi      Rs. 9,99,900      1197 cc
# freq              149     24       9                14          108
#
#                      Drivetrain Cylinder_Configuration Emission_Norm  \
# count                      1260                   1254          1256
# unique                        4                      4             4
# top     FWD (Front Wheel Drive)                In-line         BS IV
# freq                        878                   1068           870
#
#           Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type   Height  \
# count                1224        1259               1198      1267     1266
# unique                  7           2                 63         6      211
# ...

# %%
data2.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Drivetrain', 'Cylinder_Configuration', 'Emission_Norm',
#        'Engine_Location', 'Fuel_System',
#        ...
#        'Paddle_Shifters', 'Leather_Wrapped_Steering', 'Automatic_Headlamps',
#        'Engine_Type', 'ASR_/_Traction_Control', 'Cruise_Control',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=134)

# %%
data2.shape
# Out:
# (1267, 134)

# %%
pd.crosstab(data1['Doors'],columns='counts')
# Out:
# col_0  counts
# Doors
# 2.0        62
# 3.0        12
# 4.0       362
# 5.0       827

# %%
clean_data.isnull().sum()
# Out:
# Make                                           75
# Model                                           0
# Variant                                         0
# Ex-Showroom_Price                               0
# Displacement                                   12
# Cylinders                                      66
# Valves_Per_Cylinder                           102
# Drivetrain                                      7
# Cylinder_Configuration                         13
# Emission_Norm                                  11
# Engine_Location                                43
# Fuel_System                                     8
# Fuel_Tank_Capacity                             69
# Fuel_Type                                       0
# Height                                          1
# Length                                          0
# Width                                          12
# Body_Type                                       6
# Doors                                           4
# ...

# %%
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
# Out:
# Cylinders                66
# Valves_Per_Cylinder     102
# Doors                     4
# Seating_Capacity          6
# Number_of_Airbags       135
# USB_Ports              1238
# dtype: int64

# %%
# Out:
# Cylinders              0
# Valves_Per_Cylinder    0
# Doors                  0
# Seating_Capacity       0
# Number_of_Airbags      0
# USB_Ports              0
# dtype: int64

# %%
clean_data['Cylinders'].value_counts()
# Out:
# 4.0     780
# 3.0     213
# 6.0     106
# 8.0      53
# 12.0     21
# 10.0     10
# 5.0      10
# 2.0       6
# 16.0      2
# Name: Cylinders, dtype: int64

# %%
clean_data['Make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            110
# Tata                100
# Toyota               82
# Honda                64
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Porsche              14
# Maruti Suzuki R      14
# Mg                   13
# Lamborghini          13
# Icml                 11
# Lexus                10
# Mini                 10
# Land Rover           10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Premier               6
# Force                 6
# Bentley               6
# Isuzu                 5
# Aston Martin          3
# Bajaj                 2
# Bugatti               2
# ...

# %%
import seaborn as manu

# %%
manu.boxplot(X_imputed['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %%
manu.countplot(clean_data['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>
