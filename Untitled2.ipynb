# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
v1=scipy.stats.norm.rvs(loc=0,scale=1,size=10)
print(v1)
print(v1.mean())
print(v1.var())
# Out:
# [-0.2376773   0.02591413  0.02635606 -0.30619949 -0.20684235  0.89494411
#   1.45538891  0.89471661  0.97074208  0.64156209]
# 0.41589048347674806
# 0.35382913631633717

# %%
sns.distplot(v1)

# %%
v2=scipy.stats.norm.rvs(loc=0,scale=1,size=1000)
#print(v2)
print(v2.mean())
print(v2.var())
sns.distplot(v2)
# Out:
# 0.005480290258373525
# 0.9618458169569933

# %%
v3=scipy.stats.norm.pdf(np.arange(-3,-1,0.01),loc=0,scale=1)
print(v3)
#sns.distplot(v3)
# Out:
# [0.00443185 0.00456659 0.00470496 0.00484703 0.0049929  0.00514264
#  0.00529634 0.0054541  0.00561598 0.0057821  0.00595253 0.00612738
#  0.00630673 0.00649068 0.00667932 0.00687277 0.0070711  0.00727444
#  0.00748287 0.00769651 0.00791545 0.00813981 0.00836969 0.0086052
#  0.00884645 0.00909356 0.00934664 0.0096058  0.00987115 0.01014283
#  0.01042093 0.0107056  0.01099694 0.01129507 0.01160014 0.01191224
#  0.01223153 0.01255811 0.01289213 0.0132337  0.01358297 0.01394006
#  0.01430511 0.01467825 0.01505962 0.01544935 0.01584758 0.01625445
#  0.0166701  0.01709467 0.0175283  0.01797113 0.01842331 0.01888498
#  0.01935628 0.01983735 0.02032836 0.02082943 0.02134071 0.02186237
#  0.02239453 0.02293735 0.02349099 0.02405557 0.02463127 0.02521822
#  0.02581658 0.02642649 0.0270481  0.02768157 0.02832704 0.02898466
#  0.02965458 0.03033696 0.03103193 0.03173965 0.03246027 0.03319392
#  0.03394076 0.03470094 0.03547459 0.03626187 0.03706291 0.03787786
# ...

# %%
prob_under_neg1=scipy.stats.norm.cdf(x=-1,loc=0,scale=1)
prob_over_neg1=1-prob_under_neg1
print(2*prob_over_neg1
# Out:
# 1.6826894921370859

# %%
1-scipy.stats.norm.cdf(x=-1,loc=0,scale=1)
# Out:
# 0.8413447460685429

# %%
plt.fill_between(x=np.arange(-3,3,0.01),
y1= scipy.stats.norm.pdf(np.arange(-3,3,0.01)),
facecolor='blue',
alpha=0.5)
plt.vlines(x=-1,ymin=0,ymax=0.24,linestyles='dashed')

# %%
scipy.stats.norm.cdf(x=-1,loc = 0,scale= 1)
# Out:
# 0.15865525393145707

# %%
plt.fill_between(x=np.arange(-3,-1,0.01),
y1= scipy.stats.norm.pdf(np.arange(-3,-1,0.01)),
facecolor='blue',
alpha=0.5)
plt.fill_between(x=np.arange(-1,3,0.01),
y1= scipy.stats.norm.pdf(np.arange(-1,3,0.01)),
facecolor='red',
alpha=0.5)
plt.text(x=2,y=.02,s=round(prob_under_neg1,3))
plt.vlines(x=-1,ymin=0,ymax=0.24,linestyles='dashed')

# %% [markdown]
# ### Right Tails

# %%
plt.fill_between(x=np.arange(-3,-1,0.01),
y1= scipy.stats.norm.pdf(np.arange(-3,-1,0.01)),
facecolor='blue',
alpha=0.5)
plt.fill_between(x=np.arange(-1,3,0.01),
y1= scipy.stats.norm.pdf(np.arange(-1,3,0.01)),
facecolor='red',
alpha=0.5)
plt.text(x=1,y=.02,s=round(prob_over_neg1,3))
plt.vlines(x=-1,ymin=0,ymax=0.24,linestyles='dashed')

# %% [markdown]
# ### Bound

# %%
prob_over_pos1=1-scipy.stats.norm.cdf(x=1,loc = 0,scale= 1)
prob_over_pos1+prob_under_neg1
# Out:
# 0.31731050786291415

# %%
plt.fill_between(x=np.arange(-3,-1,0.01),
y1= scipy.stats.norm.pdf(np.arange(-3,-1,0.01)),
facecolor='blue',
alpha=0.5)
plt.fill_between(x=np.arange(-1,1,0.01),
y1= scipy.stats.norm.pdf(np.arange(-1,1,0.01)),
facecolor='red',
alpha=0.5)
plt.fill_between(x=np.arange(1,3,0.01),
y1= scipy.stats.norm.pdf(np.arange(1,3,0.01)),
facecolor='green',
alpha=0.5)
plt.text(x=-2,y=.02,s=round(prob_under_neg1,3))
plt.text(x=0,y=.02,s=round(1-2*prob_under_neg1,3))
plt.text(x=1,y=.02,s=round(prob_over_neg1,3))
plt.vlines(x=-1,ymin=0,ymax=0.24,linestyles='dashed')

# %% [markdown]
# ### Ques 11

# %%
prob_under_neg=scipy.stats.norm.cdf(x=-1.5,loc=0,scale=1)
prob_over_pos=1-scipy.stats.norm.cdf(x=2,loc=0,scale=1)

prob_between=1-(prob_under_neg+prob_over_pos)
prob_between
# Out:
# 0.9104426667829627

# %%
#scipy.stats.norm.pdf(-1.5)
scipy.stats.norm.pdf(2)
# Out:
# 0.05399096651318806

# %%
plt.fill_between(x=np.arange(-3,-1.5,0.01),
y1= scipy.stats.norm.pdf(np.arange(-3,-1.5,0.01)),
facecolor='blue',
alpha=0.5)
plt.fill_between(x=np.arange(-1.5,2,0.01),
y1= scipy.stats.norm.pdf(np.arange(-1.5,2,0.01)),
facecolor='red',
alpha=0.5)
plt.fill_between(x=np.arange(2,3,0.01),
y1= scipy.stats.norm.pdf(np.arange(2,3,0.01)),
facecolor='green',
alpha=0.5)
plt.text(x=-2,y=.02,s=round(prob_under_neg,3))
plt.text(x=0,y=.02,s=round(prob_between,3))
plt.text(x=1,y=.02,s=round(prob_over_pos,3))
plt.vlines(x=-1.5,ymin=0,ymax=0.129,linestyles='dashed')
plt.vlines(x=2,ymin=0,ymax=0.053,linestyles='dashed')

# %% [markdown]
# ### Inverse prob function ppf

# %%
q_val=scipy.stats.norm.cdf(x=-1,loc=0,scale=1)
q_val
# Out:
# 0.15865525393145707

# %%
scipy.stats.norm.ppf(q_val)
# Out:
# -1.0

# %%
scipy.stats.binom.rvs(n=10,p=.5,size=15, random_state=0)
# Out:
# array([5, 6, 5, 5, 5, 6, 5, 7, 8, 5, 6, 5, 5, 7, 3])

# %%
ax=sns.distplot(scipy.stats.binom.rvs(size=500,n=10,p=0.5,random_state=0),kde=True,hist_kws={"color": 'r','alpha':.8})
ax.set(xlabel='No. of successes',ylabel='Frequency of success in a given trial')
# Out:
# [Text(0, 0.5, 'Frequency of success in a given trial'),
#  Text(0.5, 0, 'No. of successes')]

# %%
scipy.stats.binom.pmf(n=20,p=0.5,k=9)
# Out:
# 0.16017913818359344

# %%
k_range=np.arange(0,10)
scipy.stats.binom.pmf(n=20,p=0.5,k=k_range)
sum(scipy.stats.binom.pmf(n=20,p=0.5,k=k_range))
# Out:
# 0.4119014739990231

# %%
scipy.stats.binom.cdf(n=20,p=0.5,k=9)
# Out:
# 0.41190147399902316

# %%
cars_data=pd.read_csv('cars_sampled.csv' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-0fc00f940e6c> in <module>
# ----> 1 cars_data=pd.read_csv('cars_sampled.csv' )
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...
